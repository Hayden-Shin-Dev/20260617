# %% [markdown]
# # 환경설정

# %%
# 다음 명령으로 파이썬 가상 환경을 생성한다.
# !python -m venv .venv

# %%
python -m pip install ipykernel
python -m pip install ipywidgets

# %%
python -m pip install upgrade pip

# %%
.\v-.venv\Scripts\Activate.ps1
